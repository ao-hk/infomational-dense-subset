# %%
# %reload_ext dimagic

# %%
# %%diagrams dot
# graph {
#     rankdir=LR;
#     1[label=<Z<SUB>1</SUB>>];
#     2[label=<Z<SUB>2</SUB>>];
#     3[label=<Z<SUB>3</SUB>>];
#     4[label=<Z<SUB>4</SUB>>];
#     5[label=<Z<SUB>5</SUB>>];
#     1 -- 2 [label=<X<SUB>a</SUB>>];
#     2 -- 3 [label=<X<SUB>b</SUB>>];
#     3 -- 1 [label=<X<SUB>c</SUB>>];
#     3 -- 4 [label=<X<SUB>d</SUB>>];
#     4 -- 5 [label=<X<SUB>e</SUB>>];
#     5 -- 3 [label=<X<SUB>f</SUB>>];
# }
# Out:
# (node:27839) V8: /opt/conda/lib/node_modules/diagrams/node_modules/viz.js/viz.js:33 Invalid asm.js: Function definition doesn't match use
# (Use `node --trace-warnings ...` to show where the warning was created)

# %%
# !cp -rf graph.svg info-net-touching-triangles.svg

# %%
# %%diagrams dot
# graph {
#     rankdir=LR;
#     1[label=<Z<SUB>1</SUB>>];
#     2[label=<Z<SUB>2</SUB>>];
#     3[label=<Z<SUB>3</SUB>>];
#     4[label=<Z<SUB>4</SUB>>];
#     5[label=<Z<SUB>5</SUB>>];
#     subgraph cluster1 {
#         1 -- 2 [label=<X<SUB>a</SUB>>];
#         2 -- 3 [label=<X<SUB>b</SUB>>];
#         3 -- 1 [label=<X<SUB>c</SUB>>];
#         label=<C<SUB>1</SUB>>;
#     }
#     3 -- 4 [label=<X<SUB>d</SUB>>];
#     subgraph cluster3 {
#         4 -- 5 [label=<X<SUB>e</SUB>>];
#         5 -- 3 [label=<X<SUB>f</SUB>>];
#         label=<C<SUB>3</SUB>>;
#     }
# }
# Out:
# (node:27854) V8: /opt/conda/lib/node_modules/diagrams/node_modules/viz.js/viz.js:33 Invalid asm.js: Function definition doesn't match use
# (Use `node --trace-warnings ...` to show where the warning was created)

# %%
# !cp -rf graph.svg info-net-touching-triangles-C1-C3.svg

# %%
# %%diagrams dot
# strict digraph {
#     compound=true;
#     rankdir=LR;
#     node [style=filled,color=white];
#     1[label=<X<SUB>1</SUB>>];
#     2[label=<X<SUB>2</SUB>>];
#     3[label=<X<SUB>3</SUB>>];
#     4[label=<X<SUB>4</SUB>>];
#     5[label=<X<SUB>5</SUB>>];
#         subgraph clusterY1 {
#             style=filled;
#             color=lightblue;
#             1;
#             label=<Y<SUB>1</SUB>>;
#         }
#         subgraph clusterY2 {
#             style=filled;
#             color=lightblue;
#             2;
#             label=<Y<SUB>2</SUB>>;
#         }
#         subgraph clusterY3 {
#             style=filled;
#             color=lightblue;
#             3;
#             label=<Y<SUB>3</SUB>>;
#         }
#         1 -> 2 [label=<X<SUB>a</SUB>>,lhead=clusterY2];
#         2 -> 3 [label=<X<SUB>b</SUB>>,lhead=clusterY3];
#         1 -> 3 [label=<X<SUB>c</SUB>>,lhead=clusterY3];
#
#     3 -> 4 [label=<X<SUB>d</SUB>>,lhead=clusterY4];
#
#         subgraph clusterY4 {
#             style=filled;
#             color=lightblue;
#             4;
#             label=<Y<SUB>4</SUB>>;
#         }
#         subgraph clusterY5 {
#             style=filled;
#             color=lightblue;
#             5;
#             label=<Y<SUB>5</SUB>>;
#         }
#         4 -> 5 [label=<X<SUB>e</SUB>>,lhead=clusterY5];
#         3 -> 5 [label=<X<SUB>f</SUB>>,lhead=clusterY5];
#
# }
# Out:
# (node:21817) V8: /opt/conda/lib/node_modules/diagrams/node_modules/viz.js/viz.js:33 Invalid asm.js: Function definition doesn't match use
# (Use `node --trace-warnings ...` to show where the warning was created)

# %%
# !cp -rf graph.svg directed-info-net-touching-triangles.svg

# %%
# %%diagrams dot
# strict digraph {
#     compound=true;
#     rankdir=LR;
#     node [style=filled,color=white];
#     1[label=<X<SUB>1</SUB>>];
#     2[label=<X<SUB>2</SUB>>];
#     3[label=<X<SUB>3</SUB>>];
#     4[label=<X<SUB>4</SUB>>];
#     5[label=<X<SUB>5</SUB>>];
#     subgraph cluster1 {
#         subgraph clusterY1 {
#             style=filled;
#             color=lightblue;
#             1;
#             label=<Y<SUB>1</SUB>>;
#         }
#         subgraph clusterY2 {
#             style=filled;
#             color=lightblue;
#             2;
#             label=<Y<SUB>2</SUB>>;
#         }
#         subgraph clusterY3 {
#             style=filled;
#             color=lightblue;
#             3;
#             label=<Y<SUB>3</SUB>>;
#         }
#         1 -> 2 [label=<X<SUB>a</SUB>>,lhead=clusterY2];
#         2 -> 3 [label=<X<SUB>b</SUB>>,lhead=clusterY3];
#         1 -> 3 [label=<X<SUB>c</SUB>>,lhead=clusterY3];
#         label=<C<SUB>1</SUB>>;
#     }
#     3 -> 4 [label=<X<SUB>d</SUB>>,lhead=clusterY4];
#     subgraph cluster3 {
#         subgraph clusterY4 {
#             style=filled;
#             color=lightblue;
#             4;
#             label=<Y<SUB>4</SUB>>;
#         }
#         subgraph clusterY5 {
#             style=filled;
#             color=lightblue;
#             5;
#             label=<Y<SUB>5</SUB>>;
#         }
#         4 -> 5 [label=<X<SUB>e</SUB>>,lhead=clusterY5];
#         3 -> 5 [label=<X<SUB>f</SUB>>,lhead=clusterY5];
#         label=<C<SUB>3</SUB>>;
#     }
# }
# Out:
# (node:21671) V8: /opt/conda/lib/node_modules/diagrams/node_modules/viz.js/viz.js:33 Invalid asm.js: Function definition doesn't match use
# (Use `node --trace-warnings ...` to show where the warning was created)

# %%
# !cp -rf graph.svg directed-info-net-touching-triangles-C1-C3.svg

# %%
# %%diagrams dot
# strict graph {
#     compound=true;
#     rankdir=LR;
#     1;
#     2;
#     3;
#     4;
#     5;
#     subgraph cluster1 {
#         1 -- 2 [label=<a>];
#         2 -- 3 [label=<b>];
#         1 -- 3 [label=<c>];
#         label=<C<SUB>1</SUB>>;
#     }
#     3 -- 4 [label=<d>];
#     subgraph cluster3 {
#         4 -- 5 [label=<e>];
#         3 -- 5 [label=<f>];
#         label=<C<SUB>3</SUB>>;
#     }
# }
# Out:
# (node:21998) V8: /opt/conda/lib/node_modules/diagrams/node_modules/viz.js/viz.js:33 Invalid asm.js: Function definition doesn't match use
# (Use `node --trace-warnings ...` to show where the warning was created)

# %%
# !cp -rf graph.svg touching-triangles-C1-C3.svg

# %%
# %%diagrams dot
# strict digraph {
#     compound=true;
#     rankdir=LR;
#     1;
#     2;
#     3;
#     4;
#     5;
#     subgraph cluster1 {
#         1 -> 2 [label=<a>];
#         2 -> 3 [label=<b>];
#         1 -> 3 [label=<c>];
#         label=<C<SUB>1</SUB>>;
#     }
#     3 -> 4 [label=<d>];
#     subgraph cluster3 {
#         4 -> 5 [label=<e>];
#         3 -> 5 [label=<f>];
#         label=<C<SUB>3</SUB>>;
#     }
# }
# Out:
# (node:22021) V8: /opt/conda/lib/node_modules/diagrams/node_modules/viz.js/viz.js:33 Invalid asm.js: Function definition doesn't match use
# (Use `node --trace-warnings ...` to show where the warning was created)

# %%
# !cp -rf graph.svg directed-touching-triangles-C1-C3.svg
